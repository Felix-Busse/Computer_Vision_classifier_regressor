# %% [markdown]
# # Analyzing images
# Comparing networks of dense layers to convolutional networks on simple image analyses.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sc
import tensorflow.keras as ks

# %% [markdown]
# ## Generator functions for sample images
# Defining functions that generate images with circles/squares in it. See docstring for details

# %%
def create_image_w_square(im_size_x=200, im_size_y=200, fill_color=[255, 255, 255],
                          sq_size=30, sq_color=[255, 128, 0]):
    '''Creates a numpy array with three dimensions, which represents an color image.
    The picture will hold a square on an arbitary position.
    Size of image and square, as well as the color of background and square my be specified.
    Besides the image the position of the square (its center position) and its area in pixels is returned'''
    # Generating image with background color
    image = np.full(shape=(im_size_x, im_size_y, 3), fill_value=fill_color)
    # Determing random position for square
    coord_x = np.random.randint(low=0, high=(im_size_x - sq_size))
    coord_y = np.random.randint(low=0, high=(im_size_y - sq_size))
    # Filling square in the image by scpecifying its color value on all three layers
    for i in range(3):
        image[coord_x:coord_x + sq_size, coord_y:coord_y + sq_size, i] = sq_color[i]
    return image, [coord_x + sq_size/2, coord_y + sq_size/2], sq_size**2

def create_image_w_circle(im_size_x=200, im_size_y=200, fill_color=[255, 255, 255],
                          circle_r=17, circle_color=[255, 128, 0]):
    '''Creates a numpy array with three dimensions, which represents an color image.
    The picture will hold a circle on an arbitary position.
    Size of image and circle, as well as the color of background and circle my be specified.
    Besides the image the position of the circle and its area in pixels is returned'''
    # Generating image with background color
    image = np.full(shape=(im_size_x, im_size_y, 3), fill_value=fill_color)
    # Determing coordinates for center of circle
    coord_x = np.random.randint(low=circle_r, high=(im_size_x - circle_r))
    coord_y = np.random.randint(low=circle_r, high=(im_size_y - circle_r))
    # Filling circle in the image by specifying its color value on all three layers
    for i in range(3):
        # Creating a meshgrid of image size and than calculate from that, whether position is in circle
        mesh = np.meshgrid(range(im_size_y), range(im_size_x))
        mesh[0] -= coord_y
        mesh[1] -= coord_x
        mask = np.sqrt(mesh[0]**2 + mesh[1]**2) < circle_r
        # Write new color on image, where pixels are within radius of circle
        image[mask, i] = circle_color[i]
    return image, [coord_x, coord_y], np.pi*circle_r**2

def samples_squares(sample_size=2300, im_sizex=60, im_size_y=60, fill_color=[255, 255, 255],
                    sq_color='random', sq_size=[30, 30]):
    '''Function return list of samples composed of images generated by function 
    "create_image_w_square()" and list of list containing x- and y-position of center of square and area of
    square (in px). See doc string of this function for details of images.
    Define size of square in image as a list of min and max value.
    Fill_color (background of image) and sq_color (color of square) are lists of three
    color values or string "random" for choosing random color in every image.'''
    samples = []
    target = []
    for i in range(sample_size):
        # Defining color of square for this iteration
        pattern_color = []
        if (sq_color == 'random'):
            # Choosing random color
            for j in range(3):
                pattern_color.append(np.random.randint(low=0, high=255))
        else:
            # sq_color already contains color value
            pattern_color = sq_color
        # Defining color of background for this iteration
        background_color = []
        if (fill_color == 'random'):
            # Choosing random color
            for j in range(3):
                background_color.append(np.random.randint(low=0, high=255))
        else:
            # fill_color already contained color value
            background_color = fill_color
        # Determing size of square for this iteration
        pattern_size = np.random.randint(low=sq_size[0], high=sq_size[1] + 1)
        # Calling image creator function and append image and its informations to samples resp. target
        image, coord, area = create_image_w_square(im_size_x=60, im_size_y=60, fill_color=background_color,
                                               sq_color=pattern_color, sq_size=pattern_size)
        samples.append(image)
        target.append([coord[0], coord[1], area])
    return samples, target

# Sample preprocessing (normalizing colors on 0 to 1 values)
def preprocessing(samples):
    """Function takes iterable of images and returnes numpy array of images scaled to color
    values from 0 to 1"""
    samples_processed = np.array(samples).astype('float')
    samples_processed /= 255
    return samples_processed

# Defining functions to preprocess area information
def area_preprocessing(target):
    """Function takes output with target information of sample image generator function. It returns
    1D numpy array with area (size of structure) information scaled to values 0 to 1 and float-value
    indicating the maximum size of structure found in samples."""
    target = np.array(target)[:, 2].astype('float')
    maximum = target.max()
    target /=  (maximum / 2)
    target -= 1
    return target, maximum

def inv_area_preprocessing(areas, maximum):
    """Inverse function to "area_preprocessing". Returns integer valued area (size of structure), when
    input of area information scaled to -1 to 1 values and maxmium values is given."""
    result = areas.copy()
    result += 1
    result /= 2
    result *= maximum
    return result.round(0).astype('int')

# %% [markdown]
# ## Generating sample of images with same colored pattern
# 200 x 200 pixel images, containing same sized squares and circles.

# %%
# Defining number of samples
sample_size = 2300

# Filling list with sample images, which contain squares or circles. Holding information about 
# circle or quare in seperate array (dummy columns).
samples = []
target = np.zeros(shape=(sample_size, 2))
for i in range(sample_size):
    if np.random.randint(low=0, high=2):
        image, *_ = create_image_w_square(im_size_x=60, im_size_y=60)
        samples.append(image)
        target[i, 0] = 1
    else:
        image, *_ = create_image_w_circle(im_size_x=60, im_size_y=60)
        samples.append(image)
        target[i, 1] = 1

# %% [markdown]
# # 1) Initializing and training of net to distinguish squares from circles
# 1. Attempt: Dense neuronal net
# 2. Attempt: Convolutional neuronal net

# %% [markdown]
# ## 1A) Training a dense net

# %%
#Defining net
Net_dense = ks.Sequential()
Net_dense.add(ks.layers.Dense(1000, activation='relu', input_shape=(10800,))) # Hidden layer
Net_dense.add(ks.layers.Dense(50, activation='relu')) # Hidden layer
Net_dense.add(ks.layers.Dense(2, activation='softmax')) # Output layer

# Compiling defined net
Net_dense.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics='accuracy')

# %%
samples_train = preprocessing(samples)

# %%
# Training the net, defining portion of samples as validation data set
history = Net_dense.fit(samples_train, target, batch_size=50, validation_split=0.1, epochs=50)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 6s 126ms/step - loss: 5.4407 - accuracy: 0.5159 - val_loss: 0.8224 - val_accuracy: 0.5348
# Epoch 2/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.9302 - accuracy: 0.5329 - val_loss: 0.6598 - val_accuracy: 0.6174
# Epoch 3/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.8096 - accuracy: 0.5454 - val_loss: 0.7311 - val_accuracy: 0.6000
# Epoch 4/50
# 42/42 [==============================] - 4s 105ms/step - loss: 0.7739 - accuracy: 0.5585 - val_loss: 0.8624 - val_accuracy: 0.4957
# Epoch 5/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.7280 - accuracy: 0.5686 - val_loss: 0.8055 - val_accuracy: 0.4957
# Epoch 6/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.7936 - accuracy: 0.5589 - val_loss: 0.6727 - val_accuracy: 0.6043
# Epoch 7/50
# 42/42 [==============================] - 5s 109ms/step - loss: 0.8539 - accuracy: 0.5643 - val_loss: 0.6608 - val_accuracy: 0.6174
# Epoch 8/50
# 42/42 [==============================] - 4s 107ms/step - loss: 0.7182 - accuracy: 0.5744 - val_loss: 0.6980 - val_accuracy: 0.6174
# Epoch 9/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.7598 - accuracy: 0.5652 - val_loss: 0.7123 - val_accuracy: 0.5000
# Epoch 10/50
# 42/42 [==============================] - 5s 111ms/step - loss: 0.8101 - accuracy: 0.5860 - val_loss: 0.7330 - val_accuracy: 0.5957
# Epoch 11/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.6357 - accuracy: 0.6415 - val_loss: 0.6462 - val_accuracy: 0.6304
# Epoch 12/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.6704 - accuracy: 0.5995 - val_loss: 0.6271 - val_accuracy: 0.6261
# Epoch 13/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.6906 - accuracy: 0.5932 - val_loss: 0.6779 - val_accuracy: 0.6087
# Epoch 14/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.6552 - accuracy: 0.6130 - val_loss: 0.6256 - val_accuracy: 0.6261
# Epoch 15/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.6698 - accuracy: 0.6304 - val_loss: 0.6226 - val_accuracy: 0.6783
# Epoch 16/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.6068 - accuracy: 0.6671 - val_loss: 0.7205 - val_accuracy: 0.4870
# Epoch 17/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.6773 - accuracy: 0.6164 - val_loss: 0.6750 - val_accuracy: 0.5609
# Epoch 18/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.6073 - accuracy: 0.6546 - val_loss: 0.7218 - val_accuracy: 0.4957
# Epoch 19/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.6668 - accuracy: 0.6246 - val_loss: 0.6008 - val_accuracy: 0.6609
# Epoch 20/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.5950 - accuracy: 0.6816 - val_loss: 0.6986 - val_accuracy: 0.6043
# Epoch 21/50
# 42/42 [==============================] - 4s 106ms/step - loss: 0.6392 - accuracy: 0.6473 - val_loss: 0.7971 - val_accuracy: 0.5478
# Epoch 22/50
# 42/42 [==============================] - 4s 107ms/step - loss: 0.7973 - accuracy: 0.5638 - val_loss: 0.6248 - val_accuracy: 0.6522
# Epoch 23/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.6387 - accuracy: 0.6309 - val_loss: 0.6495 - val_accuracy: 0.6043
# Epoch 24/50
# 42/42 [==============================] - 5s 121ms/step - loss: 0.6014 - accuracy: 0.6589 - val_loss: 0.6117 - val_accuracy: 0.6609
# Epoch 25/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.5933 - accuracy: 0.6614 - val_loss: 0.6210 - val_accuracy: 0.6478
# Epoch 26/50
# 42/42 [==============================] - 5s 109ms/step - loss: 0.6752 - accuracy: 0.5966 - val_loss: 0.6378 - val_accuracy: 0.6304
# Epoch 27/50
# 42/42 [==============================] - 4s 106ms/step - loss: 0.5857 - accuracy: 0.6783 - val_loss: 0.6542 - val_accuracy: 0.5826
# Epoch 28/50
# 42/42 [==============================] - 4s 105ms/step - loss: 0.5750 - accuracy: 0.7097 - val_loss: 0.6067 - val_accuracy: 0.6739
# Epoch 29/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.5895 - accuracy: 0.6874 - val_loss: 0.5867 - val_accuracy: 0.6696
# Epoch 30/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.6039 - accuracy: 0.6614 - val_loss: 0.6165 - val_accuracy: 0.6348
# Epoch 31/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.5733 - accuracy: 0.6889 - val_loss: 0.5865 - val_accuracy: 0.6826
# Epoch 32/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.5765 - accuracy: 0.6971 - val_loss: 0.5948 - val_accuracy: 0.7130
# Epoch 33/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.6186 - accuracy: 0.6478 - val_loss: 0.5729 - val_accuracy: 0.7261
# Epoch 34/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.5995 - accuracy: 0.6585 - val_loss: 0.5895 - val_accuracy: 0.6913
# Epoch 35/50
# 42/42 [==============================] - 5s 108ms/step - loss: 0.5450 - accuracy: 0.7473 - val_loss: 0.5953 - val_accuracy: 0.6783
# Epoch 36/50
# 42/42 [==============================] - 5s 117ms/step - loss: 0.6629 - accuracy: 0.6498 - val_loss: 0.8335 - val_accuracy: 0.4957
# Epoch 37/50
# 42/42 [==============================] - 5s 119ms/step - loss: 0.6119 - accuracy: 0.6710 - val_loss: 0.6290 - val_accuracy: 0.6609
# Epoch 38/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.6093 - accuracy: 0.6536 - val_loss: 0.6546 - val_accuracy: 0.5565
# Epoch 39/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.6337 - accuracy: 0.6261 - val_loss: 0.6944 - val_accuracy: 0.5043
# Epoch 40/50
# 42/42 [==============================] - 4s 106ms/step - loss: 0.5992 - accuracy: 0.6725 - val_loss: 0.5939 - val_accuracy: 0.7043
# Epoch 41/50
# 42/42 [==============================] - 5s 108ms/step - loss: 0.6194 - accuracy: 0.6444 - val_loss: 0.6034 - val_accuracy: 0.6913
# Epoch 42/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.6124 - accuracy: 0.6536 - val_loss: 0.6212 - val_accuracy: 0.6478
# Epoch 43/50
# 42/42 [==============================] - 4s 105ms/step - loss: 0.5969 - accuracy: 0.6643 - val_loss: 0.6388 - val_accuracy: 0.6174
# Epoch 44/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.5775 - accuracy: 0.7000 - val_loss: 0.6121 - val_accuracy: 0.6609
# Epoch 45/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.5677 - accuracy: 0.7135 - val_loss: 0.5957 - val_accuracy: 0.6696
# Epoch 46/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.5493 - accuracy: 0.7280 - val_loss: 0.5784 - val_accuracy: 0.7000
# Epoch 47/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.5968 - accuracy: 0.6609 - val_loss: 0.7423 - val_accuracy: 0.5130
# Epoch 48/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.6222 - accuracy: 0.6362 - val_loss: 0.5994 - val_accuracy: 0.6522
# Epoch 49/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.5616 - accuracy: 0.7111 - val_loss: 0.6125 - val_accuracy: 0.6391
# Epoch 50/50
# 42/42 [==============================] - 4s 105ms/step - loss: 0.6054 - accuracy: 0.6604 - val_loss: 0.6334 - val_accuracy: 0.6217

# %%
# Plotting loss-function and accuracy on training and evaluation batch. 
plt.rcParams["figure.figsize"] = [10, 6] # Defining figure size
fig, axs = plt.subplots(1, 2) # Plot contains two subplots
fig.tight_layout(pad=5) # For spacing between subplots

axs[0].set_ylabel('Loss (Categorical Crossentropy)') # left plot y-axis label
axs[0].set_xlabel('Epochs') # left plot x-axis label
axs[0].plot(history.history['loss'], color='red', label='loss') # plot loss-function in left figure

axs[1].set_ylabel('Accuracy') # right plot y-axis label
axs[1].set_xlabel('Epochs') # right plot x-axis label
ax2 = axs[1].twinx() # generate second axis to commonly plot accuracy on training and evaluation batch
ax2.sharey(axs[1]) # Both share y-axis
axs[1].plot(history.history['accuracy'], color='blue'
            , label='Accuracy on training batch') # Plot accuracy on training batch with blue color 
ax2.plot(history.history['val_accuracy'], color='green'
         , label='Accuracy on evaluation batch') # Plot accuracy on evaluation batch with green color
fig.suptitle('Performance dense network', fontsize=16)
fig.legend()

# %% [markdown]
# Conclusion: The network is learning, but slowly. Too slow for performance of my system.

# %% [markdown]
# ## 1B) Training a convolutional network on same problem

# %%
# 2. Attempt: Convolutional neuronal network
Net_conv = ks.Sequential()
Net_conv.add(ks.layers.Conv2D(input_shape=(samples[0].shape), filters=20, kernel_size=[7, 7]
                              , activation='tanh', padding='same'))
Net_conv.add(ks.layers.AveragePooling2D(pool_size=6))
Net_conv.add(ks.layers.Conv2D(filters=10, kernel_size=[7, 7]
                              , activation='tanh', padding='same'))
Net_conv.add(ks.layers.Flatten())
Net_conv.add(ks.layers.Dense(50, activation='tanh'))
Net_conv.add(ks.layers.Dense(2, activation='softmax'))

Net_conv.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics='accuracy')

# %%
samples_train_conv = preprocessing(samples)

# %%
history_conv = Net_conv.fit(samples_train_conv, target, validation_split=0.1, epochs=12)
# Out:
# Epoch 1/12
# 65/65 [==============================] - 6s 78ms/step - loss: 0.7387 - accuracy: 0.5184 - val_loss: 0.6705 - val_accuracy: 0.5870
# Epoch 2/12
# 65/65 [==============================] - 5s 73ms/step - loss: 0.6807 - accuracy: 0.5565 - val_loss: 0.6489 - val_accuracy: 0.6478
# Epoch 3/12
# 65/65 [==============================] - 5s 72ms/step - loss: 0.6810 - accuracy: 0.5725 - val_loss: 0.6481 - val_accuracy: 0.6652
# Epoch 4/12
# 65/65 [==============================] - 5s 77ms/step - loss: 0.6640 - accuracy: 0.5952 - val_loss: 0.6451 - val_accuracy: 0.6870
# Epoch 5/12
# 65/65 [==============================] - 5s 72ms/step - loss: 0.6600 - accuracy: 0.6077 - val_loss: 0.5686 - val_accuracy: 0.7348
# Epoch 6/12
# 65/65 [==============================] - 5s 76ms/step - loss: 0.4242 - accuracy: 0.8464 - val_loss: 0.1876 - val_accuracy: 0.9913
# Epoch 7/12
# 65/65 [==============================] - 5s 74ms/step - loss: 0.0965 - accuracy: 0.9990 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 8/12
# 65/65 [==============================] - 5s 72ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 9/12
# 65/65 [==============================] - 5s 75ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 10/12
# 65/65 [==============================] - 5s 76ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 11/12
# 65/65 [==============================] - 5s 74ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 12/12
# 65/65 [==============================] - 5s 79ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000

# %%
# Plotting loss-function and accuracy on training and evaluation batch. 
plt.rcParams["figure.figsize"] = [10, 6] # Defining figure size
fig, axs = plt.subplots(1, 2) # Plot contains two subplots
fig.tight_layout(pad=5) # For spacing between subplots

axs[0].set_ylabel('Loss (Categorical Crossentropy)') # left plot y-axis label
axs[0].set_xlabel('Epochs') # left plot x-axis label
axs[0].plot(history_conv.history['loss'], color='red', label='loss') # plot loss-function in left figure

axs[1].set_ylabel('Accuracy') # right plot y-axis label
axs[1].set_xlabel('Epochs') # right plot x-axis label
ax2 = axs[1].twinx() # generate second axis to commonly plot accuracy on training and evaluation batch
ax2.sharey(axs[1]) # Both share y-axis
axs[1].plot(history_conv.history['accuracy'], color='blue'
            , label='Accuracy on training batch') # Plot accuracy on training batch with blue color 
ax2.plot(history_conv.history['val_accuracy'], color='green'
         , label='Accuracy on evaluation batch') # Plot accuracy on evaluation batch with green color
fig.suptitle('Performance convolutional network\n(circle/squares with same color)', fontsize=16)
fig.legend()

# %% [markdown]
# Conclusion: Convolutional net learns much quicker, in this case calculations for one epoch took approx. same time as for dense network, but results werde very good already after 6 epochs.

# %% [markdown]
# ##  2) Performance of convolutional network on images with different colors/noise

# %% [markdown]
# ### 2A) Creating a sample set with random color for square and circle

# %%
# Defining number of samples
sample_size = 2300

# Filling list with sample images, which contain squares or circles. Holding information about 
# circle or quare in seperate array (dummy columns). Random color of squares and circles
samples_2 = []
target_2 = []
for i in range(sample_size):
    # Choosing random color
    pattern_color = []
    for j in range(3):
        pattern_color.append(np.random.randint(low=0, high=255))
    if np.random.randint(low=0, high=2):
        image, *_ = create_image_w_square(im_size_x=60, im_size_y=60, sq_color=pattern_color)
        samples_2.append(image)
        target_2.append(np.array([1, 0]))
    else:
        image, *_ = create_image_w_circle(im_size_x=60, im_size_y=60, circle_color=pattern_color)
        samples_2.append(image)
        target_2.append(np.array([0, 1]))

# %%
# Displaying example of sample 
plt.imshow(samples_2[6])

# %%
# Defining convolutional network of same layout as befor
Net_conv2 = ks.Sequential()
Net_conv2.add(ks.layers.Conv2D(input_shape=(samples[0].shape), filters=20, kernel_size=[7, 7]
                              , activation='tanh', padding='same')) # Hidden layer conv. with kernel 7x7
Net_conv2.add(ks.layers.AveragePooling2D(pool_size=6)) # Hidden layer to reduce by factor of 6 each dimension
Net_conv2.add(ks.layers.Conv2D(filters=10, kernel_size=[7, 7] # Hidden layer conv. kernel 7x7
                              , activation='tanh', padding='same'))
Net_conv2.add(ks.layers.Flatten()) # Layer to flatten all convolutional filters, so dense layers can follow
Net_conv2.add(ks.layers.Dense(50, activation='tanh')) # Hidden dense layer
Net_conv2.add(ks.layers.Dense(2, activation='softmax')) # Output layer: one hot encoding

Net_conv2.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics='accuracy')

# %%
# Normalizing colors, converting target to numpy-array
samples_train_2 = preprocessing(samples_2)
target_train_2 = np.array(target_2)

# %%
# Train network
history_conv2 = Net_conv2.fit(samples_train_2, target_train_2, validation_split=0.1, epochs=12)
# Out:
# Epoch 1/12
# 65/65 [==============================] - 6s 82ms/step - loss: 0.7139 - accuracy: 0.5329 - val_loss: 0.6933 - val_accuracy: 0.5391
# Epoch 2/12
# 65/65 [==============================] - 5s 78ms/step - loss: 0.6761 - accuracy: 0.5773 - val_loss: 0.6788 - val_accuracy: 0.5696
# Epoch 3/12
# 65/65 [==============================] - 5s 74ms/step - loss: 0.6636 - accuracy: 0.5952 - val_loss: 0.6925 - val_accuracy: 0.5870
# Epoch 4/12
# 65/65 [==============================] - 5s 73ms/step - loss: 0.6262 - accuracy: 0.6449 - val_loss: 0.5747 - val_accuracy: 0.7913
# Epoch 5/12
# 65/65 [==============================] - 5s 72ms/step - loss: 0.4048 - accuracy: 0.8671 - val_loss: 0.1924 - val_accuracy: 0.9870
# Epoch 6/12
# 65/65 [==============================] - 5s 79ms/step - loss: 0.0904 - accuracy: 0.9986 - val_loss: 0.0464 - val_accuracy: 1.0000
# Epoch 7/12
# 65/65 [==============================] - 5s 76ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 8/12
# 65/65 [==============================] - 5s 73ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 9/12
# 65/65 [==============================] - 5s 77ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 10/12
# 65/65 [==============================] - 5s 77ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 11/12
# 65/65 [==============================] - 5s 73ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 12/12
# 65/65 [==============================] - 5s 77ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000

# %%
# Plotting loss-function and accuracy on training and evaluation batch. 
plt.rcParams["figure.figsize"] = [10, 6] # Defining figure size
fig, axs = plt.subplots(1, 2) # Plot contains two subplots
fig.tight_layout(pad=6) # For spacing between subplots

axs[0].set_ylabel('Loss (Categorical Crossentropy)') # left plot y-axis label
axs[0].set_xlabel('Epochs') # left plot x-axis label
axs[0].plot(history_conv2.history['loss'], color='red', label='loss') # plot loss-function in left figure

axs[1].set_ylabel('Accuracy') # right plot y-axis label
axs[1].set_xlabel('Epochs') # right plot x-axis label
ax2 = axs[1].twinx() # generate second axis to commonly plot accuracy on training and evaluation batch
ax2.sharey(axs[1]) # Both share y-axis
axs[1].plot(history_conv2.history['accuracy'], color='blue'
            , label='Accuracy on training batch') # Plot accuracy on training batch with blue color 
ax2.plot(history_conv2.history['val_accuracy'], color='green'
         , label='Accuracy on evaluation batch') # Plot accuracy on evaluation batch with green color
fig.suptitle('Performance convolutional network\n(circles/squares with\ndifferent colors, no noise)', fontsize=16)
fig.legend()

# %% [markdown]
# Conclusion: Trainingof net is comparable fast as with same color pattern.

# %% [markdown]
# ### 2B) Add noise to same sample as in 2A)

# %%
# Function to add some percentage of noise (pixel with random color) to one image
def add_noise_image(image, noise_frac):
    no_px_modify = np.int_(len(image.flatten()) * noise_frac) # calculate how many pixels to modify
    for i in range(no_px_modify):
        coord_x = np.random.randint(low=0, high=image.shape[1]) # choose x and y position randomly
        coord_y = np.random.randint(low=0, high=image.shape[0])
        for j in range(3):
            image[coord_x, coord_y, j] = np.random.randint(low=0, high=255) # fill all 3 layers 
            # at choosen position with random value to obtain random color value
    return(image)

# Function to add noise to a list of images
def add_noise(samples, noise_frac):
    for i, image in enumerate(samples):
        image = add_noise_image(image, noise_frac)
    return(samples)

# Adding noise to sample set
samples_3 = add_noise(samples_2, 0.3) # Randomizing 30% of all pixel

# %%
# Displaying example of sample 
plt.imshow(samples_2[6])

# %%
# Defining convolutional network of same layout as befor
Net_conv3 = ks.Sequential()
Net_conv3.add(ks.layers.Conv2D(input_shape=(samples[0].shape), filters=20, kernel_size=[7, 7]
                              , activation='tanh', padding='same')) # Hidden layer conv. with kernel 7x7
Net_conv3.add(ks.layers.AveragePooling2D(pool_size=6)) # Hidden layer to reduce by factor of 6 each dimension
Net_conv3.add(ks.layers.Conv2D(filters=10, kernel_size=[7, 7] # Hidden layer conv. kernel 7x7
                              , activation='tanh', padding='same'))
Net_conv3.add(ks.layers.Flatten()) # Layer to flatten all convolutional filters, so dense layers can follow
Net_conv3.add(ks.layers.Dense(50, activation='tanh')) # Hidden dense layer
Net_conv3.add(ks.layers.Dense(2, activation='softmax')) # Output layer: one hot encoding

Net_conv3.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics='accuracy')

# %%
# Normalizing colors values, converting target to numpy_array
samples_train_3 = preprocessing(samples_3)
target_train_3 = np.array(target_2)

# %%
# Train network
history_conv3 = Net_conv3.fit(samples_train_3, target_train_3, validation_split=0.1, epochs=40)
# Out:
# Epoch 1/40
# 65/65 [==============================] - 6s 77ms/step - loss: 0.6950 - accuracy: 0.5604 - val_loss: 0.6626 - val_accuracy: 0.6174
# Epoch 2/40
# 65/65 [==============================] - 5s 78ms/step - loss: 0.6624 - accuracy: 0.5932 - val_loss: 0.6939 - val_accuracy: 0.5130
# Epoch 3/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.6629 - accuracy: 0.5903 - val_loss: 0.6868 - val_accuracy: 0.5826
# Epoch 4/40
# 65/65 [==============================] - 5s 70ms/step - loss: 0.6487 - accuracy: 0.6246 - val_loss: 0.6883 - val_accuracy: 0.5957
# Epoch 5/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.6327 - accuracy: 0.6386 - val_loss: 0.7100 - val_accuracy: 0.5261
# Epoch 6/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.6249 - accuracy: 0.6570 - val_loss: 0.7532 - val_accuracy: 0.5000
# Epoch 7/40
# 65/65 [==============================] - 5s 70ms/step - loss: 0.6196 - accuracy: 0.6512 - val_loss: 0.7428 - val_accuracy: 0.5130
# Epoch 8/40
# 65/65 [==============================] - 5s 72ms/step - loss: 0.6063 - accuracy: 0.6691 - val_loss: 0.7140 - val_accuracy: 0.5304
# Epoch 9/40
# 65/65 [==============================] - 5s 74ms/step - loss: 0.5932 - accuracy: 0.6734 - val_loss: 0.7317 - val_accuracy: 0.5435
# Epoch 10/40
# 65/65 [==============================] - 5s 72ms/step - loss: 0.5782 - accuracy: 0.6908 - val_loss: 0.7537 - val_accuracy: 0.5652
# Epoch 11/40
# 65/65 [==============================] - 5s 70ms/step - loss: 0.5596 - accuracy: 0.7121 - val_loss: 0.7667 - val_accuracy: 0.5522
# Epoch 12/40
# 65/65 [==============================] - 5s 72ms/step - loss: 0.5496 - accuracy: 0.7184 - val_loss: 0.8331 - val_accuracy: 0.5130
# Epoch 13/40
# 65/65 [==============================] - 5s 72ms/step - loss: 0.5263 - accuracy: 0.7411 - val_loss: 0.8060 - val_accuracy: 0.5957
# Epoch 14/40
# 65/65 [==============================] - 5s 76ms/step - loss: 0.5154 - accuracy: 0.7502 - val_loss: 0.7749 - val_accuracy: 0.5522
# Epoch 15/40
# 65/65 [==============================] - 5s 74ms/step - loss: 0.4830 - accuracy: 0.7657 - val_loss: 0.7543 - val_accuracy: 0.5609
# Epoch 16/40
# 65/65 [==============================] - 5s 71ms/step - loss: 0.4298 - accuracy: 0.8072 - val_loss: 0.6635 - val_accuracy: 0.6565
# Epoch 17/40
# 65/65 [==============================] - 5s 78ms/step - loss: 0.2916 - accuracy: 0.9058 - val_loss: 0.3758 - val_accuracy: 0.8435
# Epoch 18/40
# 65/65 [==============================] - 5s 78ms/step - loss: 0.1666 - accuracy: 0.9599 - val_loss: 0.2263 - val_accuracy: 0.9217
# Epoch 19/40
# 65/65 [==============================] - 5s 79ms/step - loss: 0.0793 - accuracy: 0.9908 - val_loss: 0.1209 - val_accuracy: 0.9696
# Epoch 20/40
# 65/65 [==============================] - 5s 82ms/step - loss: 0.0477 - accuracy: 0.9937 - val_loss: 0.0823 - val_accuracy: 0.9913
# Epoch 21/40
# 65/65 [==============================] - 6s 88ms/step - loss: 0.0281 - accuracy: 0.9990 - val_loss: 0.0640 - val_accuracy: 0.9870
# Epoch 22/40
# 65/65 [==============================] - 5s 83ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9826
# Epoch 23/40
# 65/65 [==============================] - 5s 79ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9913
# Epoch 24/40
# 65/65 [==============================] - 5s 74ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9913
# Epoch 25/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9913
# Epoch 26/40
# 65/65 [==============================] - 5s 74ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9913
# Epoch 27/40
# 65/65 [==============================] - 5s 79ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9913
# Epoch 28/40
# 65/65 [==============================] - 5s 75ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9957
# Epoch 29/40
# 65/65 [==============================] - 5s 71ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9913
# Epoch 30/40
# 65/65 [==============================] - 5s 71ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9957
# Epoch 31/40
# 65/65 [==============================] - 5s 75ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9957
# Epoch 32/40
# 65/65 [==============================] - 5s 81ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9957
# Epoch 33/40
# 65/65 [==============================] - 5s 80ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9957
# Epoch 34/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9957
# Epoch 35/40
# 65/65 [==============================] - 5s 74ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 36/40
# 65/65 [==============================] - 5s 83ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9957
# Epoch 37/40
# 65/65 [==============================] - 6s 88ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 38/40
# 65/65 [==============================] - 5s 82ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9957
# Epoch 39/40
# 65/65 [==============================] - 5s 79ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 40/40
# 65/65 [==============================] - 5s 81ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9957

# %%
# Plotting loss-function and accuracy on training and evaluation batch. 
plt.rcParams["figure.figsize"] = [10, 6] # Defining figure size
fig, axs = plt.subplots(1, 2) # Plot contains two subplots
fig.tight_layout(pad=6) # For spacing between subplots

axs[0].set_ylabel('Loss (Categorical Crossentropy)') # left plot y-axis label
axs[0].set_xlabel('Epochs') # left plot x-axis label
axs[0].plot(history_conv3.history['loss'], color='red', label='loss') # plot loss-function in left figure

axs[1].set_ylabel('Accuracy') # right plot y-axis label
axs[1].set_xlabel('Epochs') # right plot x-axis label
ax2 = axs[1].twinx() # generate second axis to commonly plot accuracy on training and evaluation batch
ax2.sharey(axs[1]) # Both share y-axis
axs[1].plot(history_conv3.history['accuracy'], color='blue'
            , label='Accuracy on training batch') # Plot accuracy on training batch with blue color 
ax2.plot(history_conv3.history['val_accuracy'], color='green'
         , label='Accuracy on evaluation batch') # Plot accuracy on evaluation batch with green color
fig.suptitle('Performance convolutional network\n(circles/squares with\ndifferent colors, 30% noise added)', fontsize=16)
fig.legend()

# %% [markdown]
# Conclusion: 30% of noise significantly slowes down learning progress of net.

# %% [markdown]
# # 3) Distinguishing on samples that containe different sized squares/circles

# %%
# Creating samples of random sized and colored circles and squares
# Defining number of samples
sample_size = 2300

# Filling list with sample images, which contain squares or circles. Holding information about 
# circle or quare in seperate array (dummy columns). Random color of squares and circles, random size
samples_4 = []
target_4 = []
for i in range(sample_size):
    # Choosing random color
    pattern_color = []
    for j in range(3):
        pattern_color.append(np.random.randint(low=0, high=255))
    if np.random.randint(low=0, high=2):
        image, *_ = create_image_w_square(im_size_x=60, im_size_y=60, sq_color=pattern_color, 
                                          sq_size=np.random.randint(low=9, high=40))
        samples_4.append(image)
        target_4.append(np.array([1, 0]))
    else:
        image, *_ = create_image_w_circle(im_size_x=60, im_size_y=60, circle_color=pattern_color, 
                                          circle_r=np.random.randint(low=5, high=23))
        samples_4.append(image)
        target_4.append(np.array([0, 1]))

# %%
# Displaying example of sample data
plt.imshow(samples_4[7])

# %%
# Defining convolutional network of same layout as befor
Net_conv4 = ks.Sequential()
Net_conv4.add(ks.layers.Conv2D(input_shape=(samples[0].shape), filters=20, kernel_size=[7, 7]
                              , activation='tanh', padding='same')) # Hidden layer conv. with kernel 7x7
Net_conv4.add(ks.layers.AveragePooling2D(pool_size=6)) # Hidden layer to reduce by factor of 6 each dimension
Net_conv4.add(ks.layers.Conv2D(filters=10, kernel_size=[7, 7] # Hidden layer conv. kernel 7x7
                              , activation='tanh', padding='same'))
Net_conv4.add(ks.layers.Flatten()) # Layer to flatten all convolutional filters, so dense layers can follow
Net_conv4.add(ks.layers.Dense(50, activation='tanh')) # Hidden dense layer
Net_conv4.add(ks.layers.Dense(2, activation='softmax')) # Output layer: one hot encoding

Net_conv4.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics='accuracy')

# %%
# Sample preprocessing: normalizing colors to values 0 to 1, converting target to array
samples_train_4 = preprocessing(samples_4)
target_train_4 = np.array(target_4)

# %%
history_4 = Net_conv4.fit(samples_train_4, target_train_4, validation_split=0.1, epochs=40)
# Out:
# Epoch 1/40
# 65/65 [==============================] - 6s 78ms/step - loss: 0.7686 - accuracy: 0.4918 - val_loss: 0.6966 - val_accuracy: 0.4957
# Epoch 2/40
# 65/65 [==============================] - 4s 68ms/step - loss: 0.6895 - accuracy: 0.5290 - val_loss: 0.6912 - val_accuracy: 0.5130
# Epoch 3/40
# 65/65 [==============================] - 5s 70ms/step - loss: 0.6925 - accuracy: 0.5488 - val_loss: 0.6956 - val_accuracy: 0.5000
# Epoch 4/40
# 65/65 [==============================] - 4s 68ms/step - loss: 0.6793 - accuracy: 0.5570 - val_loss: 0.7087 - val_accuracy: 0.5391
# Epoch 5/40
# 65/65 [==============================] - 5s 79ms/step - loss: 0.6817 - accuracy: 0.5671 - val_loss: 0.6886 - val_accuracy: 0.5435
# Epoch 6/40
# 65/65 [==============================] - 6s 88ms/step - loss: 0.6698 - accuracy: 0.5884 - val_loss: 0.7223 - val_accuracy: 0.5478
# Epoch 7/40
# 65/65 [==============================] - 6s 95ms/step - loss: 0.6767 - accuracy: 0.5797 - val_loss: 0.7635 - val_accuracy: 0.5000
# Epoch 8/40
# 65/65 [==============================] - 5s 78ms/step - loss: 0.6750 - accuracy: 0.5797 - val_loss: 0.7075 - val_accuracy: 0.5130
# Epoch 9/40
# 65/65 [==============================] - 5s 72ms/step - loss: 0.6682 - accuracy: 0.5812 - val_loss: 0.7046 - val_accuracy: 0.5348
# Epoch 10/40
# 65/65 [==============================] - 5s 78ms/step - loss: 0.6624 - accuracy: 0.5894 - val_loss: 0.6982 - val_accuracy: 0.5348
# Epoch 11/40
# 65/65 [==============================] - 5s 77ms/step - loss: 0.6702 - accuracy: 0.5802 - val_loss: 0.7048 - val_accuracy: 0.5522
# Epoch 12/40
# 65/65 [==============================] - 6s 99ms/step - loss: 0.6665 - accuracy: 0.5961 - val_loss: 0.6994 - val_accuracy: 0.5174
# Epoch 13/40
# 65/65 [==============================] - 7s 104ms/step - loss: 0.6597 - accuracy: 0.6043 - val_loss: 0.6931 - val_accuracy: 0.5652
# Epoch 14/40
# 65/65 [==============================] - 5s 70ms/step - loss: 0.6498 - accuracy: 0.6188 - val_loss: 0.6946 - val_accuracy: 0.5435
# Epoch 15/40
# 65/65 [==============================] - 5s 80ms/step - loss: 0.6584 - accuracy: 0.6130 - val_loss: 0.6948 - val_accuracy: 0.5565
# Epoch 16/40
# 65/65 [==============================] - 6s 93ms/step - loss: 0.6444 - accuracy: 0.6130 - val_loss: 0.6766 - val_accuracy: 0.5478
# Epoch 17/40
# 65/65 [==============================] - 6s 89ms/step - loss: 0.6247 - accuracy: 0.6411 - val_loss: 0.6463 - val_accuracy: 0.5739
# Epoch 18/40
# 65/65 [==============================] - 4s 68ms/step - loss: 0.5730 - accuracy: 0.7063 - val_loss: 0.6061 - val_accuracy: 0.6739
# Epoch 19/40
# 65/65 [==============================] - 4s 69ms/step - loss: 0.5197 - accuracy: 0.7464 - val_loss: 0.5416 - val_accuracy: 0.7261
# Epoch 20/40
# 65/65 [==============================] - 5s 70ms/step - loss: 0.4626 - accuracy: 0.7739 - val_loss: 0.5003 - val_accuracy: 0.7478
# Epoch 21/40
# 65/65 [==============================] - 5s 80ms/step - loss: 0.4091 - accuracy: 0.8111 - val_loss: 0.4425 - val_accuracy: 0.8130
# Epoch 22/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3716 - accuracy: 0.8275 - val_loss: 0.4888 - val_accuracy: 0.7174
# Epoch 23/40
# 65/65 [==============================] - 5s 72ms/step - loss: 0.3405 - accuracy: 0.8420 - val_loss: 0.3806 - val_accuracy: 0.8043
# Epoch 24/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.3218 - accuracy: 0.8483 - val_loss: 0.3735 - val_accuracy: 0.8043
# Epoch 25/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.2918 - accuracy: 0.8734 - val_loss: 0.3664 - val_accuracy: 0.8261
# Epoch 26/40
# 65/65 [==============================] - 5s 77ms/step - loss: 0.2621 - accuracy: 0.8899 - val_loss: 0.3488 - val_accuracy: 0.8261
# Epoch 27/40
# 65/65 [==============================] - 5s 82ms/step - loss: 0.2557 - accuracy: 0.8918 - val_loss: 0.3179 - val_accuracy: 0.8522
# Epoch 28/40
# 65/65 [==============================] - 6s 88ms/step - loss: 0.2388 - accuracy: 0.8942 - val_loss: 0.3448 - val_accuracy: 0.8348
# Epoch 29/40
# 65/65 [==============================] - 6s 92ms/step - loss: 0.2161 - accuracy: 0.9097 - val_loss: 0.3201 - val_accuracy: 0.8565
# Epoch 30/40
# 65/65 [==============================] - 6s 95ms/step - loss: 0.2011 - accuracy: 0.9169 - val_loss: 0.3428 - val_accuracy: 0.8435
# Epoch 31/40
# 65/65 [==============================] - 5s 76ms/step - loss: 0.1923 - accuracy: 0.9193 - val_loss: 0.3537 - val_accuracy: 0.8522
# Epoch 32/40
# 65/65 [==============================] - 5s 77ms/step - loss: 0.1745 - accuracy: 0.9304 - val_loss: 0.3062 - val_accuracy: 0.8478
# Epoch 33/40
# 65/65 [==============================] - 4s 69ms/step - loss: 0.1598 - accuracy: 0.9401 - val_loss: 0.2934 - val_accuracy: 0.8652
# Epoch 34/40
# 65/65 [==============================] - 5s 73ms/step - loss: 0.1417 - accuracy: 0.9478 - val_loss: 0.2873 - val_accuracy: 0.8565
# Epoch 35/40
# 65/65 [==============================] - 6s 89ms/step - loss: 0.1385 - accuracy: 0.9488 - val_loss: 0.2624 - val_accuracy: 0.8609
# Epoch 36/40
# 65/65 [==============================] - 5s 80ms/step - loss: 0.1247 - accuracy: 0.9585 - val_loss: 0.2793 - val_accuracy: 0.8739
# Epoch 37/40
# 65/65 [==============================] - 5s 79ms/step - loss: 0.1216 - accuracy: 0.9551 - val_loss: 0.2805 - val_accuracy: 0.8783
# Epoch 38/40
# 65/65 [==============================] - 4s 69ms/step - loss: 0.1138 - accuracy: 0.9623 - val_loss: 0.2608 - val_accuracy: 0.8739
# Epoch 39/40
# 65/65 [==============================] - 5s 77ms/step - loss: 0.1030 - accuracy: 0.9633 - val_loss: 0.2592 - val_accuracy: 0.8913
# Epoch 40/40
# 65/65 [==============================] - 4s 69ms/step - loss: 0.1074 - accuracy: 0.9628 - val_loss: 0.2658 - val_accuracy: 0.8826

# %%
# Plotting loss-function and accuracy on training and evaluation batch. 
plt.rcParams["figure.figsize"] = [10, 6] # Defining figure size
fig, axs = plt.subplots(1, 2) # Plot contains two subplots
fig.tight_layout(pad=6) # For spacing between subplots

axs[0].set_ylabel('Loss (Categorical Crossentropy)') # left plot y-axis label
axs[0].set_xlabel('Epochs') # left plot x-axis label
axs[0].plot(history_4.history['loss'], color='red', label='loss') # plot loss-function in left figure

axs[1].set_ylabel('Accuracy') # right plot y-axis label
axs[1].set_xlabel('Epochs') # right plot x-axis label
ax2 = axs[1].twinx() # generate second axis to commonly plot accuracy on training and evaluation batch
ax2.sharey(axs[1]) # Both share y-axis
axs[1].plot(history_4.history['accuracy'], color='blue'
            , label='Accuracy on training batch') # Plot accuracy on training batch with blue color 
ax2.plot(history_4.history['val_accuracy'], color='green'
         , label='Accuracy on evaluation batch') # Plot accuracy on evaluation batch with green color
fig.suptitle('Performance convolutional network\n(circles/squares with\ndifferent colors, different sizes)', fontsize=16)
fig.legend()

# %% [markdown]
# Conclusion: Differenz sized squares and circles are slowing learning - even more than 30% noise.

# %% [markdown]
# # 4) Measuring size of squares

# %%
# Create samples and targets
samples_5, target_5 = samples_squares(2300, sq_size=[5, 30])
# Preprocessing: normalizing color values to values 0 to 1, 
samples_train_5 = preprocessing(samples_5)
# converting target_5 to array and normalizing to -1 to 1 values
target_train_5, target_max = area_preprocessing(target_5)

# %%
# Displaying exsample of data
plt.imshow(samples_5[5], origin='lower')

# %%
# Defining convolutional network
Net_conv5 = ks.Sequential()
Net_conv5.add(ks.layers.Conv2D(input_shape=(samples_5[0].shape), filters=20, kernel_size=[3, 3]
                              , activation='tanh', padding='same')) # Hidden layer conv. with kernel 7x7
#Net_conv5.add(ks.layers.Dropout(0.1))
Net_conv5.add(ks.layers.AveragePooling2D(pool_size=3, padding='same')) # Hidden layer to reduce by factor of 3 each dimension
Net_conv5.add(ks.layers.Conv2D(filters=10, kernel_size=[7, 7] # Hidden layer conv. kernel 5x5
                              , activation='tanh', padding='same'))
Net_conv5.add(ks.layers.AveragePooling2D(pool_size=2, padding='same')) # Hidden layer to reduce by factor of 3 each dimension
Net_conv5.add(ks.layers.Conv2D(filters=10, kernel_size=[7, 7] # Hidden layer conv. kernel 5x5
                              , activation='tanh', padding='same'))
Net_conv5.add(ks.layers.Flatten()) # Layer to flatten all convolutional filters, so dense layers can follow
Net_conv5.add(ks.layers.Dense(25, activation='tanh')) # Hidden dense layer
Net_conv5.add(ks.layers.Dense(1, activation='linear')) # Output layer: one hot encoding

Net_conv5.compile(optimizer='adam', loss='mean_squared_error', metrics=[ks.metrics.RootMeanSquaredError()])

# %%
history_5 = Net_conv5.fit(samples_train_5, target_train_5, batch_size=64,
                          validation_split=0.1, epochs=50)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 6s 141ms/step - loss: 0.4296 - root_mean_squared_error: 0.6554 - val_loss: 0.2743 - val_root_mean_squared_error: 0.5237
# Epoch 2/50
# 33/33 [==============================] - 5s 140ms/step - loss: 0.2400 - root_mean_squared_error: 0.4899 - val_loss: 0.2143 - val_root_mean_squared_error: 0.4629
# Epoch 3/50
# 33/33 [==============================] - 4s 133ms/step - loss: 0.2055 - root_mean_squared_error: 0.4533 - val_loss: 0.1930 - val_root_mean_squared_error: 0.4393
# Epoch 4/50
# 33/33 [==============================] - 4s 132ms/step - loss: 0.1790 - root_mean_squared_error: 0.4230 - val_loss: 0.1779 - val_root_mean_squared_error: 0.4218
# Epoch 5/50
# 33/33 [==============================] - 5s 143ms/step - loss: 0.1676 - root_mean_squared_error: 0.4094 - val_loss: 0.1609 - val_root_mean_squared_error: 0.4012
# Epoch 6/50
# 33/33 [==============================] - 4s 126ms/step - loss: 0.1568 - root_mean_squared_error: 0.3960 - val_loss: 0.1415 - val_root_mean_squared_error: 0.3761
# Epoch 7/50
# 33/33 [==============================] - 4s 130ms/step - loss: 0.1434 - root_mean_squared_error: 0.3787 - val_loss: 0.1465 - val_root_mean_squared_error: 0.3828
# Epoch 8/50
# 33/33 [==============================] - 4s 130ms/step - loss: 0.1399 - root_mean_squared_error: 0.3740 - val_loss: 0.1315 - val_root_mean_squared_error: 0.3626
# Epoch 9/50
# 33/33 [==============================] - 4s 128ms/step - loss: 0.1376 - root_mean_squared_error: 0.3710 - val_loss: 0.1315 - val_root_mean_squared_error: 0.3627
# Epoch 10/50
# 33/33 [==============================] - 4s 130ms/step - loss: 0.1226 - root_mean_squared_error: 0.3501 - val_loss: 0.1095 - val_root_mean_squared_error: 0.3309
# Epoch 11/50
# 33/33 [==============================] - 4s 129ms/step - loss: 0.1168 - root_mean_squared_error: 0.3417 - val_loss: 0.1265 - val_root_mean_squared_error: 0.3557
# Epoch 12/50
# 33/33 [==============================] - 4s 130ms/step - loss: 0.1225 - root_mean_squared_error: 0.3500 - val_loss: 0.1063 - val_root_mean_squared_error: 0.3260
# Epoch 13/50
# 33/33 [==============================] - 4s 127ms/step - loss: 0.1018 - root_mean_squared_error: 0.3190 - val_loss: 0.0989 - val_root_mean_squared_error: 0.3144
# Epoch 14/50
# 33/33 [==============================] - 4s 129ms/step - loss: 0.1035 - root_mean_squared_error: 0.3216 - val_loss: 0.0905 - val_root_mean_squared_error: 0.3009
# Epoch 15/50
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0898 - root_mean_squared_error: 0.2997 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3036
# Epoch 16/50
# 33/33 [==============================] - 4s 132ms/step - loss: 0.1135 - root_mean_squared_error: 0.3370 - val_loss: 0.1078 - val_root_mean_squared_error: 0.3284
# Epoch 17/50
# 33/33 [==============================] - 5s 144ms/step - loss: 0.0850 - root_mean_squared_error: 0.2916 - val_loss: 0.0657 - val_root_mean_squared_error: 0.2564
# Epoch 18/50
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0776 - root_mean_squared_error: 0.2785 - val_loss: 0.0797 - val_root_mean_squared_error: 0.2823
# Epoch 19/50
# 33/33 [==============================] - 5s 146ms/step - loss: 0.0754 - root_mean_squared_error: 0.2745 - val_loss: 0.0588 - val_root_mean_squared_error: 0.2426
# Epoch 20/50
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0647 - root_mean_squared_error: 0.2544 - val_loss: 0.0605 - val_root_mean_squared_error: 0.2461
# Epoch 21/50
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0647 - root_mean_squared_error: 0.2544 - val_loss: 0.0521 - val_root_mean_squared_error: 0.2283
# Epoch 22/50
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0622 - root_mean_squared_error: 0.2494 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2316
# Epoch 23/50
# 33/33 [==============================] - 5s 137ms/step - loss: 0.0540 - root_mean_squared_error: 0.2323 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2494
# Epoch 24/50
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0642 - root_mean_squared_error: 0.2533 - val_loss: 0.1479 - val_root_mean_squared_error: 0.3846
# Epoch 25/50
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0621 - root_mean_squared_error: 0.2493 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2088
# Epoch 26/50
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0556 - root_mean_squared_error: 0.2358 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2086
# Epoch 27/50
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1986
# Epoch 28/50
# 33/33 [==============================] - 5s 139ms/step - loss: 0.0475 - root_mean_squared_error: 0.2180 - val_loss: 0.0427 - val_root_mean_squared_error: 0.2067
# Epoch 29/50
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0502 - root_mean_squared_error: 0.2241 - val_loss: 0.0607 - val_root_mean_squared_error: 0.2464
# Epoch 30/50
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0506 - root_mean_squared_error: 0.2249 - val_loss: 0.0799 - val_root_mean_squared_error: 0.2827
# Epoch 31/50
# 33/33 [==============================] - 5s 144ms/step - loss: 0.0537 - root_mean_squared_error: 0.2316 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 32/50
# 33/33 [==============================] - 5s 152ms/step - loss: 0.0431 - root_mean_squared_error: 0.2075 - val_loss: 0.0638 - val_root_mean_squared_error: 0.2526
# Epoch 33/50
# 33/33 [==============================] - 4s 135ms/step - loss: 0.0513 - root_mean_squared_error: 0.2264 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# Epoch 34/50
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0400 - root_mean_squared_error: 0.2000 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 35/50
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0327 - root_mean_squared_error: 0.1808 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1649
# Epoch 36/50
# 33/33 [==============================] - 5s 156ms/step - loss: 0.0421 - root_mean_squared_error: 0.2053 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1893
# Epoch 37/50
# 33/33 [==============================] - 5s 144ms/step - loss: 0.0368 - root_mean_squared_error: 0.1917 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1836
# Epoch 38/50
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0357 - root_mean_squared_error: 0.1891 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548
# Epoch 39/50
# 33/33 [==============================] - 4s 135ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1594
# Epoch 40/50
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0284 - root_mean_squared_error: 0.1685 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 41/50
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0286 - root_mean_squared_error: 0.1691 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1467
# Epoch 42/50
# 33/33 [==============================] - 4s 135ms/step - loss: 0.0318 - root_mean_squared_error: 0.1784 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1326
# Epoch 43/50
# 33/33 [==============================] - 5s 142ms/step - loss: 0.0273 - root_mean_squared_error: 0.1652 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1561
# Epoch 44/50
# 33/33 [==============================] - 4s 136ms/step - loss: 0.0286 - root_mean_squared_error: 0.1693 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536
# Epoch 45/50
# 33/33 [==============================] - 5s 138ms/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1352
# Epoch 46/50
# 33/33 [==============================] - 5s 137ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 47/50
# 33/33 [==============================] - 5s 140ms/step - loss: 0.0251 - root_mean_squared_error: 0.1586 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# Epoch 48/50
# 33/33 [==============================] - 5s 145ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 49/50
# 33/33 [==============================] - 5s 143ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1036
# Epoch 50/50
# 33/33 [==============================] - 5s 139ms/step - loss: 0.0216 - root_mean_squared_error: 0.1468 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297

# %%
# Plotting loss-function and RMS on training and evaluation batch. 
plt.rcParams["figure.figsize"] = [10, 6] # Defining figure size
fig, axs = plt.subplots(1, 2) # Plot contains two subplots
fig.tight_layout(pad=6) # For spacing between subplots

axs[0].set_ylabel('Root-mean-square-error') # left plot y-axis label
axs[0].set_xlabel('Epochs') # left plot x-axis label
axs[0].plot(history_5.history['loss'], color='red', label='loss') # plot loss-function in left figure

axs[1].set_ylabel('Root-mean-square-error') # right plot y-axis label
axs[1].set_xlabel('Epochs') # right plot x-axis label
ax2 = axs[1].twinx() # generate second axis to commonly plot accuracy on training and evaluation batch
ax2.sharey(axs[1]) # Both share y-axis
axs[1].plot(history_5.history['root_mean_squared_error'], color='blue'
            , label='RMS on training batch') # Plot accuracy on training batch with blue color 
ax2.plot(history_5.history['val_root_mean_squared_error'], color='green'
         , label='RMS on evaluation batch') # Plot accuracy on evaluation batch with green color
ax2.axis('off')
fig.suptitle('Performance convolutional network\n(measuring area of squares with\ndifferent colors, different sizes)', fontsize=16)
fig.legend()

# %%
# Generating new samples for validation on larger data set
validation_sample, validation_target = samples_squares(5000, sq_size=[5, 30])

# Preprocessing: normalizing color values to values 0 to 1, 
# converting target_5 to array and normalizing to -1 to 1 values
validation_sample = preprocessing(validation_sample)
validation_areas_normalized, validation_maximum = area_preprocessing(validation_target)

y = Net_conv5.predict(validation_sample)
# Out:
# 157/157 [==============================] - 3s 21ms/step

# %%
# Comparing on real area sizes
result_areas = inv_area_preprocessing(y, validation_maximum)
validation_areas = np.array(validation_target)[:, 2].astype('int')
# Calculationg pearson correlation and p-value (for one-sided test for positive correlation)
pearson_result_areas = sc.stats.pearsonr(result_areas.flatten(), 
                                         validation_areas.flatten(), alternative='greater')
print(f'Pearson-coefficient is: {pearson_result_areas.correlation:.3f}\nP-value is: {pearson_result_areas.pvalue:.2f}')
# Out:
# Pearson-coefficient is: 0.744
# P-value is: 0.00

# %% [markdown]
# ### Calculating statistics of results

# %%
# Search for all different area sizes in target and calculate mean and standard deviation of
# those in the predicted values of the model.
predicts_mean = []
predicts_std = []
# store all unique values of targets in validation data set
unique_validation_areas = np.unique(validation_areas)
# loop through all unique values of targets in validation data set
for i, value in enumerate(unique_validation_areas):
    # Calculate and store mean and std of corresponding predicted area sizes
    predicts_mean.append(result_areas[validation_areas == value].mean())
    predicts_std.append(result_areas[validation_areas == value].std())
# Converting to arrays
predicts_mean = np.array(predicts_mean)
predicts_std = np.array(predicts_std)
# Plot target values and predicted values with errorbars
fig, ax = plt.subplots()
# Create second axis to plot target and predicted values
ax2 = ax.twinx()
ax2.sharey(ax)
ax2.set_ylabel('Area size (px)')
ax.set_ylabel('Area size (px)')
ax.set_xlabel('Area size (px)')
# Plot predicted values with errorbars (std)
ax.errorbar(unique_validation_areas, predicts_mean, predicts_std, fmt='o', color='red', 
           label='prediction')
# Plot target values
ax2.plot(unique_validation_areas, unique_validation_areas, 'ok', label='target')
ax2.axis('off')
fig.legend()
fig.suptitle('Comparission of predicted area sizes (with their std) and target area sizes')
# Out:
# Text(0.5, 0.98, 'Comparission of predicted area sizes (with their std) and target area sizes')

# %% [markdown]
# For values less than 200 px, target value tend to lay outside of standard deviation of
# predicted values, when using 7x7 Kernel for first layer of net. After changing to 3x3 Kernel on first layer of net, predictions are not systematically weaker for small area sizes.
